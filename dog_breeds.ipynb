# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Seattle_Pet_Licenses.csv')

# %%
df.head()
# Out:
#   License Issue Date  License Number Animal's Name Species  \
# 0      April 19 2003        200097.0   Tinkerdelle     Cat
# 1   February 07 2006         75432.0        Pepper     Cat
# 2     August 31 2012        578859.0      Grey Fox     Cat
# 3   November 14 2013        832989.0        Hannah     Cat
# 4      April 03 2014        433713.0         Daisy     Cat
#
#         Primary Breed Secondary Breed ZIP Code
# 0  Domestic Shorthair             NaN    98116
# 1                Manx             Mix    98103
# 2             Siamese             Mix    98125
# 3   Domestic Longhair             NaN    98133
# 4  Domestic Shorthair             NaN    98117

# %%
df_dog = df[df["Species"]=='Dog']

# %%
df_dog["Primary Breed"].unique()
# Out:
# array(['Pug', 'Boxer', 'Hound', 'Kuvasz', 'Mix', 'Retriever, Labrador',
#        'Dachshund, Miniature Smooth Haired', 'Spaniel, Irish Water',
#        'Chihuahua, Short Coat', 'Spaniel, English Springer',
#        'Australian Shepherd', 'Schnauzer, Miniature', 'Havanese',
#        'Shih Tzu', 'Retriever, Golden', 'Bulldog, French', 'Setter, Irish',
#        'Terrier, Cairn', 'Spaniel, American Cocker', 'Rhodesian Ridgeback',
#        'Terrier, Fox, Toy', 'Shetland Sheepdog', 'Bearded Collie',
#        'Welsh Corgi, Cardigan', 'Beagle', 'Terrier, Staffordshire Bull',
#        'Terrier, Soft Coated Wheaten', 'Pomeranian',
#        'Welsh Corgi, Pembroke', 'Spaniel', 'Terrier, Airedale',
#        'Schipperke', 'Terrier, American Pit Bull', 'Greyhound',
#        'Poodle, Standard', 'Portuguese Water Dog', 'Poodle, Miniature',
#        'Terrier', 'Poodle, Toy', 'Xoloitzcuintli', 'Brittany',
#        'Terrier, American Staffordshire', 'Pointer, German Shorthaired',
#        'Terrier, Boston', 'Terrier, Manchester', 'Saint Bernard',
#        'Basset Hound', 'Retriever, Chesapeake Bay', 'Terrier, Bull',
#        'Dachshund, Standard Long Haired', 'Terrier, Jack Russell',
#        'Chinese Shar-Pei', 'Miniature Pinscher', 'Lhasa Apso', 'Shepherd',
#        'Terrier, Silky', 'German Shepherd',
#        'Dachshund, Standard Smooth Haired', 'Collie, Rough',
#        'Norwegian Elkhound', 'Vizsla, Smooth Haired', 'Bichon Frise',
#        'Terrier, Border', 'Rottweiler', 'Beauceron', 'Terrier, Welsh',
#        'Terrier, Yorkshire', 'Terrier, West Highland White',
#        'Belgian Malinois', 'Siberian Husky', 'Alaskan Husky',
#        'Bulldog, English', 'Australian Cattle Dog', 'Terrier, Irish',
#        'Bernese Mountain Dog', 'Spaniel, Cavalier King Charles',
#        'Terrier, Norfolk', 'Bloodhound', 'Entlebucher Mountain Dog',
#        'Mastiff', 'American Eskimo', 'Pointer', 'Terrier, Rat',
#        'Pointer, German Wirehaired', 'Shiba Inu', 'Retriever, Flat-Coated',
#        'Bulldog, American', 'Maltese', 'Terrier, Australian', 'Chow Chow',
#        'Border Collie', 'Afghan Hound', 'Coonhound', 'Terrier, Fox, Wire',
#        'Kooikerhondje', 'Whippet', 'Japanese Chin', 'Akita', 'Retriever',
#        'Coton de Tulear', 'Schnauzer, Standard', 'Dogue de Bordeaux',
#        'Alaskan Malamute', 'Terrier, Fox, Smooth',
#        'Spaniel, Welsh Springer', 'Catahoula Leopard dog', 'Pekingese',
#        'Great Dane', 'Papillon', 'Plott Hound',
#        'Australian Shepherd, Miniature', 'Braque Francais Gascogne',
#        'Australian Kelpie', 'Doberman Pinscher', 'Weimaraner',
#        'Terrier, Tibetan', 'Dachshund, Standard Wire Haired', 'Dalmatian',
#        'Cane Corso', 'Samoyed', 'Keeshond', 'Collie, Smooth',
#        'Terrier, Pit Bull', 'Chihuahua, Long Coat', 'Lagotto Romagnolo',
#        'Greater Swiss Mountain Dog', 'Basenji', 'Puli', 'Lowchen',
#        'Newfoundland', 'Dachshund, Miniature Long Haired',
#        'American Blue Heeler', 'Spaniel, English Cocker',
#        'Terrier, Dandie Dinmont', 'Old English Sheepdog',
#        'Coonhound, Treeing Walker', 'Spaniel, Tibetan',
#        'Terrier, Scottish', 'Great Pyrenees', 'Terrier, Russell',
#        'Griffon, Brussels', 'Retriever, Curly Coated',
#        'Retriever, Nova Scotia Duck Tolling', 'Canadian Eskimo',
#        'Caucasian Mountain Dog', 'Korean Jindo', 'Norwegian Lundehund',
#        'Italian Greyhound', 'Belgian Tervuren', 'Mexican Hairless',
#        'Bouvier des Flandres', 'Spaniel, Clumber', 'Bullmastiff',
#        'Tibetan Mastiff', 'Spaniel, Field', 'Olde English Bulldogge',
#        'Bulldog', 'Terrier, Lakeland',
#        'Mixed Breed, Medium (up to 44 lbs fully grown)',
#        'Terrier, Parson Russell', 'Briard', 'Griffon, Wirehaired Pointing',
#        'Dachshund, Miniature Wire Haired', 'Icelandic Sheepdog',
#        'Foxhound, American', 'Affenpinscher', 'Leonberger',
#        'Setter, Gordon', 'Coonhound, Black and Tan', 'Portuguese Podengo',
#        'Spanish Water Dog', 'Terrier, Kerry Blue', 'Harrier',
#        'Cur, Mountain', 'Anatolian Shepherd', 'Terrier, Sealyham',
#        'Terrier, Miniature Bull', 'Alaskan Klee Kai', 'Chinese Crested',
#        'Schnauzer, Giant', 'Belgian Sheepdog', 'Terrier, Norwich',
#        'Coonhound, Redbone', 'Perro de Presa Canario', 'Spinone Italiano',
#        'Canaan', 'German Pinscher', 'Borzoi', 'Spaniel, English Toy',
#        'Irish Wolfhound', 'Mixed Breed, Large (over 44 lbs fully grown)',
#        'Cur, Black-Mouth', 'Setter, English', 'Pudelpointer',
#        'Griffon Vendeen, Petit Basset', 'Saluki', 'Chinook', 'Kangal',
#        'Deerhound, Scottish', 'Carolina Dog', 'Neapolitan Mastiff',
#        'Munsterlander, Large ', 'Terrier, Bedlington', 'Finnish Spitz',
#        'Cirneco dell Etna', 'Ibizan Hound', 'Norwegian Buhund',
#        'Spaniel, Sussex', 'Appenzeller Sennenhunde', 'Bolognese', 'Akbash',
#        'English Shepherd', 'Dutch Shepherd', 'American Bandogge Mastiff',
#        'English Mastiff', 'Argentine Dogo', 'Swedish Vallhund', 'Kai Ken',
#        'Foxhound, English', 'Pharaoh Hound', 'Boerboel',
#        'Terrier, English Staffordshire', 'Terrier, Glen of Imaal',
#        'Eurasier', 'Karelian Bear Dog', 'Austrian Pinscher',
#        'Australian Koolie', 'Finnish Lapphund', 'Silken Windhound',
#        'Thai Ridgeback', 'German Spitz', 'Czechoslovakian Wolfdog',
#        'Greenland Dog', 'Otterhound', 'Landseer', 'American Bullnese',
#        'Terrier, Black Russian', 'Terrier, Patterdale',
#        'Estrela Mountain Dog', 'Coonhound, Bluetick',
#        'Peruvian Inca Orchid', 'Bouvier des Ardennes',
#        'Mixed Breed, Small (under 24 lbs fully grown)', 'Barbet',
#        'Brittany, French', 'Pyrenean Shepherd', 'Stabyhoun',
#        'German Shepherd, King', 'Alapaha Blue Blood Bulldog',
#        'Dutch Smoushond', 'Feist', 'Treeing Tennessee Brindle',
#        'Picardy Sheepdog', 'White Swiss Shepherd (Berger Blanc Suisse)',
#        'McNab Herding Dog', 'Vizsla, Wire Haired', 'Saarloos Wolfdog',
#        'Spaniel, American Water', 'Lacy', 'Perdiguero Gallego',
#        'Shiloh Shepherd', 'American Indian Dog', 'Maremma Sheepdog',
#        'Dutch Sheepdog', 'Griffon Vendeen, Grand Basset',
#        'Podenco Canario', 'Coonhound, American English',
#        'Royal Bahamian Potcake', 'Munsterlander,Small', 'Komondor',
#        'Setter, Irish Red and White', 'Japanese Spitz',
#        'Braque Francais Pyrenees', 'Spaniel, Boykin', 'Tahitian Bear Dog',
#        'Podenco Gallego', 'Terrier, Skye'], dtype=object)

# %%
pd.DataFrame(df_dog["Primary Breed"].unique()).to_csv('dog_breeds.csv', index=False)

# %%
# !head dog_breeds.csv
# Out:
# Pug
# Boxer
# Hound
# Kuvasz
# Mix
# "Retriever, Labrador"
# "Dachshund, Miniature Smooth Haired"
# "Spaniel, Irish Water"
# "Chihuahua, Short Coat"
# "Spaniel, English Springer"

# %%
# Let's give dog breeds the same generative treatment

# %%
with open('dog_breeds.csv') as f:
    file = f.read()

# %%
import random
import string
import re

all_characters = string.printable
n_characters = len(all_characters)

# %%
chunk_len = 100
file_len = len(file)
def random_chunk():
    '''filelen is length of chars in file'''
    start_index = random.randint(0, file_len - chunk_len)
    end_index = start_index + chunk_len + 1
    return file[start_index:end_index]

# %%
# Build the Model
import torch
import torch.nn as nn
from torch.autograd import Variable

class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, n_layers=1):
        super(RNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        
        self.encoder = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers)
        self.decoder = nn.Linear(hidden_size, output_size)
        
    def forward(self, input, hidden):
        input = self.encoder(input.view(1,-1))
        output, hidden = self.gru(input.view(1,1,-1) ,hidden)
        output = self.decoder(output.view(1, -1))
        return output, hidden
    
    def init_hidden(self):
        return Variable(torch.zeros(self.n_layers, 1, self.hidden_size))

# %%
def char_tensor(string_):
    tensor = torch.zeros(len(string_)).long()
    for c in range(len(string_)):
        tensor[c] = all_characters.index(string_[c])
    return Variable(tensor)

print(char_tensor('abcDEF'))
# Out:
# Variable containing:
#  10
#  11
#  12
#  39
#  40
#  41
# [torch.LongTensor of size 6]

# %%
def random_training_set():
    chunk = random_chunk()
    inp = char_tensor(chunk[:-1])
    target = char_tensor(chunk[1:])
    return inp, target

# %%
# Evaluating
def evaluate(prime_str='A', predict_len=100, temperature=0.8):
    hidden = decoder.init_hidden()
    prime_input = char_tensor(prime_str)
    predicted = prime_str
    
    for p in range(len(prime_str)-1):
        _,hidden = decoder(prime_input[p], hidden)
    inp = prime_input[-1]
    
    for p in range(predict_len):
        output, hidden = decoder(inp, hidden)
        
        output_dist = output.data.view(-1).div(temperature).exp()
        top_i = torch.multinomial(output_dist, 1)[0]
        
        predicted_char = all_characters[top_i]
        predicted += predicted_char
        inp = char_tensor(predicted_char)
        
    return predicted

# %%
# Training
import time, math

def time_since(since):
    s = time.time() - since
    m = math.floor(s/60)
    s -= m*60
    return '%dm %ds' % (m,s)

# %%
def train(inp, target):
    hidden = decoder.init_hidden()
    decoder.zero_grad()
    loss=0
    
    for c in range(chunk_len):
        output, hidden = decoder(inp[c], hidden)
        loss += criterion(output, target[c])
        
    loss.backward()
    decoder_optimizer.step()
    
    return loss.data[0] / chunk_len

# %%
n_epochs = 2000
print_every = 100
plot_every=10
hidden_size = 100
n_layers = 1
lr = 0.005

decoder = RNN(n_characters, hidden_size, n_characters, n_layers)
decoder_optimizer = torch.optim.Adam(decoder.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()

start = time.time()
all_losses=[]
loss_avg = 0

for epoch in range(1, n_epochs+1):
    try:
        loss = train(*random_training_set())
        loss_avg += loss

        if epoch % print_every == 0:
            print('[%s (%d %d%%) %.4f]' % (time_since(start), epoch, epoch / n_epochs * 100, loss))
            print(evaluate('R', 100), '\n')

        if epoch % plot_every == 0:
            all_losses.append(loss_avg / plot_every)
            loss_avg = 0
    except:
        continue
# Out:
#  12s (100 5%) 2.0617]
# Rul"
# "Griff
# Setan Bulkande Doglier, ins Sheped Estinse"
# Rusater"
# "Terrierre Mard Aund
# "Terrier
# Norlis
#
#  25s (200 10%) 1.1439]
# Rerpieva
# "Terrier, Redlese
# Janese Shephound, Ming Welsh Sheepdog
# Sitcan Bull"
# Catrie
# Petter, Reepdol
#
#
#  37s (300 15%) 1.3358]
# R"
# "Terrier, For, Minarian Russel
# "Terrier, Boodlergel, Gordog
# "Terrier, Golden Chad Cancoo
# Retriever
#
#  49s (400 20%) 0.8015]
# Rie, Miniature White"
# Spanian
# Tascher
# Coon
# Terman Blue Frane Basse Kker
# "Spaniel, Russell"
# Iberman F
#
#  1s (500 25%) 0.8501]
# Royer"
# Durchound
# "Terrier, Geamatter"
# "Setter, Mott"
# American Ban Sherd, Franca Mountain Kish Watue"
#
#
#  13s (600 30%) 1.0672]
# Retre"
# Wheater"
# Schow fully grown)"
# Oldogge Bastar-"Retriever, Shepherd
# "Foxhound, Long Coated White"
#
#  25s (700 35%) 0.5338]
# Retriever, Flat-Cate de Ball"
# "Terrier, Fox, des arkman"
# "Terrier, Staffordshire"
# Retire Haired
# Austr
#
#  37s (800 40%) 0.4892]
# Redhound
# "Retriever, Cheepand White"
# Japanese Masaffordshire Bulldog
# "Terrier, Standard dyher Standar
#
#  53s (900 45%) 0.6236]
# Rich Sheepdog
# "Welsh Sheep4h Susse Pinscher
# Braque Francais Dog
# "Retriever, Walker"
# "Schnzusse
# "Terri
#
#  6s (1000 50%) 0.8834]
# Retriever, Carmollie
# "Mixed Breed, Simolkein Smooth Husky"
# Apena Inauca Scing Bernar Dog
# "Retriever,
#
#  18s (1100 55%) 0.5360]
# Retriever, Flat-Coated"
# "Terrier, Fox, Smoothound, American"
# Affenpinscher
# Leonberger
# "Setter, Irish"
#
#  31s (1200 60%) 0.5532]
# Roidger
# "Setter, English Shepherd
# Koin
# Nwerpen Malian Hound
# "Retriever, Nova Scotian Swiss Russell"
# "
#
#  43s (1300 65%) 0.4749]
# Retriever, Curly Coated"
# "Dachshund, Standard Wire Haired"
# "Spaniel, Welsh Wolfh Haired"
# Perro Ridgeb
#
#  59s (1400 70%) 0.2113]
# Retriever, Golden"
# Australian Shepherd
# "Schnauzer, Miniature (yren"
# "Coonhound, American"
# Australian
#
#  12s (1500 75%) 0.2952]
# Retriever, Flat-Coated"
# "Terrier, Lakelan"
# Beauceron
# "Terrier, Border"
# Rottherd
# Entalian Greyhound
# "T
#
#  24s (1600 80%) 0.4278]
# Retriever, Grelphan Spasian"
# "Coonhound, English"
# Pharaoh Hound
# Boerboel
# "Terrier, Parson Porso
# Samoy
#
#  37s (1700 85%) 0.3275]
# Redbone"
# Perro de Blue de Blui
# Brit Hound
# Norwegian Bordeard
# "Retriever, Curly Coated"
# "Terrier, Tibe
#
#  50s (1800 90%) 0.3803]
# Retriever, Seolke (under 24 lbs fully grown)"
# Barserian Bull"
# Briard
# "Dachshund, Miniature Bull"
# Alas
#
#  3s (1900 95%) 0.2618]
# Retriever, Staffordshire"
# Schippet Dog
# Norwegian Dog
# Potcake
# Spane
# "Terrier, Russell"
# Chith Bar Husky
#
#  15s (2000 100%) 0.3998]
# Retriever, Curl (ova Duck Tor"
# "Chihuahua, Short Coat"
# "Spaniel, American Haired"
# "Schnauzer, tired"

# %%
print(evaluate('f', 300, temperature=0.5))
# Out:
# fulling"
# Canadian Eskimo
# Caucasian Mastiff
# "Terrier, Welsh"
# "Terrier, Miniature Smooth Haired"
# "Spaniel, English Cocker"
# "Terrier, English Corgi, Cardigan"
# "Terrier, Miniature Wire Haired"
# "Spaniel, American Water"
# "Terrier, Border"
# Royal Gallego
# Shiloh Shepherd
# "Dachshund, Miniature Smooth Haired"
# "

# %%
print(evaluate('f', 300, temperature=0.1))
# Out:
# fulling"
# Canadian Elkhoundl, English"
# Pharaoha Dogooke de Blancher Mascaremanese Mamute
# "Terrier, Bedican"
# Barbee
# "Terricancais Mancais Gascogne
# Austalian Sheepdog
# "German Shar-Peike
# Mascair Dinian
# Bascain Dinoo
# "
# Porton Elg
# Oldo English Coated"
# "Bulldog, English"
# Austaliaffon Veendeen, German"
# Basca

# %%
print(evaluate('f', 400, temperature=0.95))
# Out:
# fghund, Miniature Pinscher
# Beaglo
# "Coonhound, Treeing Walker"
# Alkitz
# Carolitte
# Saint Hound
# "Vizsla, Wire Haired"
# Perdeiured
# American Mountain Dog
# Maremma Shar-Pei
# Miniature Highund
# Shiba Inca Orchimamo
# Cantanian
# "Terrier, Soft Coated"
# "Retriever, Nova Scotia Duck TollingCoat"
# Portuguese Water Dog
# "Terrier, English Staffordshire"
# "Terrier, Border"
# Royal Galled Shortuesioun
# Akita
# Retriever
# Cotondon
# "
