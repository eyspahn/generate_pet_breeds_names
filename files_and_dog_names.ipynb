# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Seattle_Pet_Licenses.csv')

# %%
df.head()
# Out:
#   License Issue Date  License Number Animal's Name Species  \
# 0      April 19 2003        200097.0   Tinkerdelle     Cat
# 1   February 07 2006         75432.0        Pepper     Cat
# 2     August 31 2012        578859.0      Grey Fox     Cat
# 3   November 14 2013        832989.0        Hannah     Cat
# 4      April 03 2014        433713.0         Daisy     Cat
#
#         Primary Breed Secondary Breed ZIP Code
# 0  Domestic Shorthair             NaN    98116
# 1                Manx             Mix    98103
# 2             Siamese             Mix    98125
# 3   Domestic Longhair             NaN    98133
# 4  Domestic Shorthair             NaN    98117

# %%
df['License Issue Date'] = pd.to_datetime(df["License Issue Date"])

# %%
# Yay, we have 2018 data in there.
df.sort_values(by=['License Issue Date'], ascending=False)
# Out:
#       License Issue Date  License Number Animal's Name Species  \
# 55960         2018-03-10        902201.0          Nala     Dog
# 19031         2018-03-10        140093.0      Mitchell     Cat
# 38020         2018-03-10        140091.0         Eddie     Dog
# 38019         2018-03-10        128110.0          Bugs     Dog
# 38018         2018-03-10        110035.0       Grendel     Dog
# 19030         2018-03-10        128111.0        Phoebe     Cat
# 19029         2018-03-10        104298.0        Scully     Cat
# 19028         2018-03-10        104297.0        Mulder     Cat
# 38021         2018-03-10        140092.0        Osbert     Dog
# 55959         2018-03-10         15970.0        Ziggie     Dog
# 55958         2018-03-10        102232.0     Caledonia     Dog
# 55957         2018-03-10        112062.0       Cricket     Dog
# 55956         2018-03-10         84139.0    Carly Rose     Dog
# 55952         2018-03-09             NaN     Ruby Rose     Dog
# 38010         2018-03-09        140918.0       Din Din     Dog
# 19024         2018-03-09         74348.0       Pickles     Cat
# 19025         2018-03-09        964212.0         Ghost     Cat
# 19026         2018-03-09        964218.0      Patinkin     Cat
# 19027         2018-03-09        107907.0          Fizz     Cat
# 55954         2018-03-09             NaN           Zoe     Dog
# 55955         2018-03-09             NaN         Chloe     Dog
# 38012         2018-03-09        140697.0      Pad Thai     Dog
# 38011         2018-03-09        140917.0         Diego     Dog
# 55951         2018-03-09        100477.0        Wombat     Dog
# 38013         2018-03-09        140916.0        Marley     Dog
# 38014         2018-03-09             NaN     Nordic IV     Dog
# 38015         2018-03-09             NaN           Leo     Dog
# 38016         2018-03-09             NaN        Kooper     Dog
# 38017         2018-03-09         84006.0          Cole     Dog
# 19023         2018-03-09         74342.0        Cowboy     Cat
# ...                  ...             ...           ...     ...
# 38033         2014-04-07         81166.0         Olive     Dog
# 38034         2014-04-07        138661.0         Annie     Dog
# 38035         2014-04-07        138618.0          Brie     Dog
# 19042         2014-04-07        834754.0         Gizmo     Dog
# 38032         2014-04-04        215429.0      Precious     Dog
# 38031         2014-04-03        280523.0          Abby     Dog
# 19041         2014-04-03        214189.0          Link     Dog
# 4             2014-04-03        433713.0         Daisy     Cat
# 38030         2014-04-03        139259.0        Po'ele     Dog
# 19040         2014-04-02        331286.0         Buddy     Dog
# 19039         2014-03-31        278788.0     Phinnegan     Dog
# 38029         2014-03-19        141023.0          Lucy     Dog
# 19038         2014-01-28         83614.0         Pepsi     Dog
# 38028         2014-01-21        212932.0         Rosie     Dog
# 19037         2014-01-17        903830.0      Mitchell     Dog
# 3             2013-11-14        832989.0        Hannah     Cat
# 38027         2012-12-01        893696.0         Fancy     Dog
# 19036         2012-11-25        899061.0          Jake     Dog
# 38025         2012-10-15        820181.0      Midnight     Dog
# 38026         2012-10-15        820182.0       Blackie     Dog
# 2             2012-08-31        578859.0      Grey Fox     Cat
# 19035         2012-08-30        584062.0        Cooper     Dog
# 38024         2011-03-29        141222.0        Jenkey     Dog
# 19034         2008-12-01        957147.0       Finigan     Dog
# 38023         2008-11-12        900555.0         Emily     Dog
# 19033         2008-03-31        135493.0         Oscar     Dog
# 19032         2008-03-20        135598.0         Buddy     Dog
# 1             2006-02-07         75432.0        Pepper     Cat
# 38022         2004-02-04        109299.0        Chivja     Dog
# 0             2003-04-19        200097.0   Tinkerdelle     Cat
#
#                             Primary Breed           Secondary Breed ZIP Code
# 55960                             Kai Ken                       NaN    98103
# 19031                  Domestic Shorthair                       Mix    98121
# 38020                              Beagle                       NaN    98108
# 38019            Spaniel, American Cocker                       NaN    98125
# 38018                           Chow Chow       Retriever, Labrador      NaN
# 19030                             Siamese               Desert Lynx    98125
# 19029                  Domestic Shorthair                       Mix    98144
# 19028                  Domestic Shorthair                       Mix    98144
# 38021                             Maltese                       Mix    98122
# 55959                  Miniature Pinscher                       NaN    98106
# 55958                Bernese Mountain Dog                       NaN    98116
# 55957                   Poodle, Miniature  Spaniel, American Cocker    98126
# 55956                 Retriever, Labrador                       NaN    98117
# 55952      Terrier, English Staffordshire                       NaN    98126
# 38010                 Australian Shepherd                       NaN    98119
# 19024                  Domestic Shorthair                       NaN    98103
# 19025                  Domestic Shorthair                       NaN    98125
# 19026                  Domestic Shorthair                       NaN    98125
# 19027                   Domestic Longhair                       NaN    98133
# 55954                     German Shepherd                       NaN    98105
# 55955                            Havanese                       NaN    98133
# 38012                    Alaskan Klee Kai                       NaN    98102
# 38011                             Maltese         Poodle, Miniature    98119
# 55951         Terrier, Staffordshire Bull                       NaN    98126
# 38013        Terrier, Soft Coated Wheaten          Poodle, Standard      NaN
# 38014                   Retriever, Golden       Retriever, Labrador    98122
# 38015                 Retriever, Labrador                Great Dane    98107
# 38016                                 Mix                       NaN    98106
# 38017                           Coonhound                       Mix    98117
# 19023                  Domestic Shorthair                       NaN    98103
# ...                                   ...                       ...      ...
# 38033                       Terrier, Bull                       NaN    98125
# 38034                        Bichon Frise         Poodle, Miniature    98125
# 38035                        Bichon Frise                       NaN    98125
# 19042                            Havanese                       NaN    98108
# 38032               Terrier, Jack Russell                       NaN    98116
# 38031                 Retriever, Labrador                       NaN    98119
# 19041                 Retriever, Labrador                       NaN    98125
# 4                      Domestic Shorthair                       NaN    98117
# 38030                 Retriever, Labrador                       NaN    98115
# 19040                Schnauzer, Miniature                       NaN    98144
# 19039                 Australian Shepherd                       NaN    98103
# 38029                   Poodle, Miniature  Spaniel, American Cocker    98199
# 19038                 Australian Shepherd            Bearded Collie    98115
# 38028                 Retriever, Labrador           German Shepherd    98199
# 19037           Spaniel, English Springer                       NaN    98144
# 3                       Domestic Longhair                       NaN    98133
# 38027                             Maltese                       NaN    98122
# 19036                 Retriever, Labrador                       NaN      NaN
# 38025               Chihuahua, Short Coat                       NaN    98118
# 38026                 Retriever, Labrador                       Mix    98118
# 2                                 Siamese                       Mix    98125
# 19035               Chihuahua, Short Coat                       NaN    98105
# 38024               Australian Cattle Dog                       Mix    98106
# 19034                Spaniel, Irish Water                       NaN    98107
# 38023                     Terrier, Boston                       NaN    98107
# 19033  Dachshund, Miniature Smooth Haired                       NaN    98104
# 19032                 Retriever, Labrador                       Mix    98133
# 1                                    Manx                       Mix    98103
# 38022                       Saint Bernard                       NaN    98101
# 0                      Domestic Shorthair                       NaN    98116
#
# [55961 rows x 7 columns]

# %%
# I think there needs to be some more data cleaning happening...
# Are there blank or short cat names?
df["Animal\'s Name"].isnull().sum()
# Out:
# 816

# %%
# !!! THERE ARE 816 ANIMALS WITHOUT NAMES!!!

# %%
df[pd.isnull(df["Animal\'s Name"])]
# Out:
#       License Issue Date  License Number Animal's Name Species  \
# 54            2015-08-06        578687.0           NaN     Cat
# 83            2015-11-16        269837.0           NaN     Cat
# 147           2015-11-30         21795.0           NaN     Cat
# 167           2015-12-02        140679.0           NaN     Cat
# 214           2015-12-15        897476.0           NaN     Cat
# 240           2015-12-18        896415.0           NaN     Cat
# 293           2016-01-08        822915.0           NaN     Cat
# 300           2016-01-13        730389.0           NaN     Cat
# 310           2016-01-25        896246.0           NaN     Cat
# 333           2016-02-16        349529.0           NaN     Cat
# 355           2016-03-03        110791.0           NaN     Cat
# 356           2016-03-03        110795.0           NaN     Cat
# 357           2016-03-03        110796.0           NaN     Cat
# 363           2016-03-03        110797.0           NaN     Cat
# 365           2016-03-03        110799.0           NaN     Cat
# 366           2016-03-03        110835.0           NaN     Cat
# 367           2016-03-03        110836.0           NaN     Cat
# 368           2016-03-03        110837.0           NaN     Cat
# 460           2016-03-08        133139.0           NaN     Cat
# 482           2016-03-09        140780.0           NaN     Cat
# 541           2016-03-12        110833.0           NaN     Cat
# 622           2016-03-16        133468.0           NaN     Cat
# 662           2016-03-19        128199.0           NaN     Cat
# 692           2016-03-22        128153.0           NaN     Cat
# 763           2016-03-28        129774.0           NaN     Cat
# 925           2016-04-07        113658.0           NaN     Cat
# 926           2016-04-07        113661.0           NaN     Cat
# 927           2016-04-07        113663.0           NaN     Cat
# 931           2016-04-07        113664.0           NaN     Cat
# 932           2016-04-07        113665.0           NaN     Cat
# ...                  ...             ...           ...     ...
# 45667         2017-01-26        127314.0           NaN     Dog
# 45672         2017-01-26         24041.0           NaN     Dog
# 46348         2017-03-08        131355.0           NaN     Dog
# 46902         2017-04-04        119878.0           NaN     Dog
# 47153         2017-04-13        119858.0           NaN     Dog
# 47184         2017-04-14         84098.0           NaN     Dog
# 47486         2017-04-26        194099.0           NaN     Dog
# 47974         2017-05-16        263830.0           NaN     Dog
# 48071         2017-05-18        361209.0           NaN     Dog
# 48687         2017-06-10        356981.0           NaN     Dog
# 48756         2017-06-13        355686.0           NaN     Dog
# 50597                Retriever, Labrador                    Mix    98105
# 50881                          Pekingese                    Mix    98118
# 51010        Terrier, Staffordshire Bull        Terrier, Boston    98117
# 51754                         Pomeranian                    NaN    98144
# 51881                     Xoloitzcuintli                    NaN    98107
# 52243                            Terrier               Shepherd    98108
# 52332                          Pekingese                    NaN    98103
# 52361                                Pug                 Beagle    98119
# 52375                Retriever, Labrador                    NaN    98136
# 52428                  Retriever, Golden       Poodle, Standard    98199
# 52440          Spaniel, English Springer                    NaN    98144
# 52513                            Terrier                    Mix    98125
# 52515                           Papillon                    NaN    98125
# 53845  Dachshund, Standard Smooth Haired                    NaN    98125
# 53961                            Terrier                    Mix    98144
# 54165                Retriever, Labrador                    NaN    98118
#
# [816 rows x 7 columns]

# %%
df = df[~pd.isnull(df["Animal\'s Name"])]

# %%
# Let's create separate names for dogs and cats.

# %%
dog_names = df[df.Species=='Dog']["Animal's Name"]

# %%
dog_names.to_csv('dog_names.csv', index=False)

# %%
cat_names = df[df.Species=='Cat']["Animal's Name"]

# %%
cat_names.to_csv('cat_names.csv', index=False)

# %%
# !head dog_names.csv
# Out:
# Winston
# Charlie
# Louie
# Finn
# Cole
# Moka
# Bill
# Moose
# Hero
# Boss

# %%
# !head cat_names.csv
# Out:
# Tinkerdelle
# Pepper
# Grey Fox
# Hannah
# Daisy
# Kukula
# Stanleigh
# Gunner
# Rhiannon
# Leto

# %%
# DOGS

# %%
# get a single long string of strain names separated by newline chars
with open('dog_names.csv') as f:
    file = f.read()

# %%
len(file)

# %%
# Following pytorch example I used previously

# %%
import random
import string
import re

all_characters = string.printable
n_characters = len(all_characters)

# %%
chunk_len = 100
file_len = len(file)
def random_chunk():
    '''filelen is length of chars in file'''
    start_index = random.randint(0, file_len - chunk_len)
    end_index = start_index + chunk_len + 1
    return file[start_index:end_index]

# %%
random_chunk()
# Out:
# 'o\nToby\nLuke\nJimmy Dean\nSedona\nWebster\nBode\nHampton\nMax\nTeddy\nDuke\nOtto\nMilo\nNova\nMax\nMax\nNazzy\nWalden'

# %%
# Build the Model
import torch
import torch.nn as nn
from torch.autograd import Variable

class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, n_layers=1):
        super(RNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        
        self.encoder = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers)
        self.decoder = nn.Linear(hidden_size, output_size)
        
    def forward(self, input, hidden):
        input = self.encoder(input.view(1,-1))
        output, hidden = self.gru(input.view(1,1,-1) ,hidden)
        output = self.decoder(output.view(1, -1))
        return output, hidden
    
    def init_hidden(self):
        return Variable(torch.zeros(self.n_layers, 1, self.hidden_size))

# %%
def char_tensor(string_):
    tensor = torch.zeros(len(string_)).long()
    for c in range(len(string_)):
        tensor[c] = all_characters.index(string_[c])
    return Variable(tensor)

print(char_tensor('abcDEF'))
# Out:
# Variable containing:
#  10
#  11
#  12
#  39
#  40
#  41
# [torch.LongTensor of size 6]

# %%
def random_training_set():
    chunk = random_chunk()
    inp = char_tensor(chunk[:-1])
    target = char_tensor(chunk[1:])
    return inp, target

# %%
# Evaluating
def evaluate(prime_str='A', predict_len=100, temperature=0.8):
    hidden = decoder.init_hidden()
    prime_input = char_tensor(prime_str)
    predicted = prime_str
    
    for p in range(len(prime_str)-1):
        _,hidden = decoder(prime_input[p], hidden)
    inp = prime_input[-1]
    
    for p in range(predict_len):
        output, hidden = decoder(inp, hidden)
        
        output_dist = output.data.view(-1).div(temperature).exp()
        top_i = torch.multinomial(output_dist, 1)[0]
        
        predicted_char = all_characters[top_i]
        predicted += predicted_char
        inp = char_tensor(predicted_char)
        
    return predicted

# %%
# Training
import time, math

def time_since(since):
    s = time.time() - since
    m = math.floor(s/60)
    s -= m*60
    return '%dm %ds' % (m,s)

# %%
def train(inp, target):
    hidden = decoder.init_hidden()
    decoder.zero_grad()
    loss=0
    
    for c in range(chunk_len):
        output, hidden = decoder(inp[c], hidden)
        loss += criterion(output, target[c])
        
    loss.backward()
    decoder_optimizer.step()
    
    return loss.data[0] / chunk_len

# %%
n_epochs = 2000
print_every = 100
plot_every=10
hidden_size = 100
n_layers = 1
lr = 0.005

decoder = RNN(n_characters, hidden_size, n_characters, n_layers)
decoder_optimizer = torch.optim.Adam(decoder.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()

start = time.time()
all_losses=[]
loss_avg = 0

for epoch in range(1, n_epochs+1):
    try:
        loss = train(*random_training_set())
        loss_avg += loss

        if epoch % print_every == 0:
            print('[%s (%d %d%%) %.4f]' % (time_since(start), epoch, epoch / n_epochs * 100, loss))
            print(evaluate('R', 100), '\n')

        if epoch % plot_every == 0:
            all_losses.append(loss_avg / plot_every)
            loss_avg = 0
    except:
        continue
# Out:
#  14s (100 5%) 2.2591]
# Rutzoe Budy
# Benery Atine Wilie
# Bika
# Bugy
# Niusta
# Arallie
# Cohe Bucy
# Farikin
# Brkiee
# Cascita Ikge Cotoo
# L
#
#  29s (200 10%) 2.2650]
# Razzs
# Pebby
# Jaxy
# Scarler
# Topy
# Silly
# parlie
# Manlie
# Pnisty
# Jaka
# Grarlie
# Roxi
# Allie
# Anddy Bele
# Maxie
# Dan
#
#  41s (300 15%) 2.2799]
# Roe
# Kachan
# Ludy
# Bosie
# Mo Duddy
# Sadie
# Dacy
# Chardie
# Leolu
# Chee
# Madie
# Caie
# Greffanaele
# Sumety
# Busha
# Gunz
#
#  57s (400 20%) 2.1085]
# Rog
# Steo
# Nalie
# Rosie
# Phippa
# Bella
# Glow
# Maley
# Noy
# Edge
# Mori
# Broso
# Jena
# Sast
# Roxie
# Lunie
# RuEn
# Lury
# Penn
#
#  12s (500 25%) 1.9606]
# RTick
# Beana
# Bangie
# Jack
# Shady
# Samcka
# Samy
# Frie
# Buntet
# Ningie
# Millie
# Jakis
# Stloe
# Ostley
# Hermo
# Gora
# Mil
#
#  26s (600 30%) 2.1313]
# Remer
# Fran
# Buddy
# Manko
# Kobina
# Luna
# Luna
# Maggie
# Bear
# Marly
# Skiter
# Louie
# Stella
# Edillen
# Ceria
# Benra
# Gee
#
#  44s (700 35%) 2.0804]
# R-!=die
# Max
# Toby
# Roa
# Kila
# Stel
# Luila
# Willson
# Pillie
# Nella
# Oliver
# Henry
# Gizmo Jasper
# Ludelo Wala
# Rosi
#
#
#  58s (800 40%) 1.8430]
# Rere
# Mazulle Mailey
# Shattie
# Zo
# Sild
# Penna
# Billy
# Clean
# Gaxter
# Billey
# Jogie
# Sophar
# Bano
# Lulu
# Gracy
# Arry
#
